# %% [markdown]
# ## Copying files from HDFS to HDFS
#
# Let us understand how to copy files with in HDFS (from one HDFS location to another HDFS location).
#
# * We can use `hdfs dfs -cp` command to copy files with in HDFS.
# * One need to have at least read permission on source folders or files and write permission on target folder for `cp` command to work as expected.

# %%
# %%sh
#
# hdfs dfs -rm -R -skipTrash /user/`whoami`/retail_db
# Out:
# Deleted /user/itversity/retail_db

# %%
# !hdfs dfs -put /data/retail_db /public

# %%
# %%sh
#
# hdfs dfs -ls /public/retail_db
# Out:
# Found 9 items
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:27 /public/retail_db/categories
# -rw-r--r--   1 itversity supergroup   10303297 2022-05-29 17:27 /public/retail_db/create_db.sql
# -rw-r--r--   1 itversity supergroup       1748 2022-05-29 17:27 /public/retail_db/create_db_tables_pg.sql
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:27 /public/retail_db/customers
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:27 /public/retail_db/departments
# -rw-r--r--   1 itversity supergroup   10297372 2022-05-29 17:27 /public/retail_db/load_db_tables_pg.sql
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:27 /public/retail_db/order_items
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:27 /public/retail_db/orders
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:27 /public/retail_db/products

# %%
# %%sh
#
# hdfs dfs -ls /user/`whoami`
# Out:
# Found 1 items
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:08 /user/itversity/.sparkStaging

# %%
# %%sh
#
# hdfs dfs -help cp
# Out:
# -cp [-f] [-p | -p[topax]] [-d] <src> ... <dst> :
#   Copy files that match the file pattern <src> to a destination.  When copying
#   multiple files, the destination must be a directory. Passing -p preserves status
#   [topax] (timestamps, ownership, permission, ACLs, XAttr). If -p is specified
#   with no <arg>, then preserves timestamps, ownership, permission. If -pa is
#   specified, then preserves permission also because ACL is a super-set of
#   permission. Passing -f overwrites the destination if it already exists. raw
#   namespace extended attributes are preserved if (1) they are supported (HDFS
#   only) and, (2) all of the source and target pathnames are in the /.reserved/raw
#   hierarchy. raw namespace xattr preservation is determined solely by the presence
#   (or absence) of the /.reserved/raw prefix and not by the -p option. Passing -d
#   will skip creation of temporary file(<dst>._COPYING_).

# %% [markdown]
# * Let us create directory to store all the folders and files related to HDFS under user space. You can review the permissions on retail_db, user have write permissions on the target folder.

# %%
# %%sh
#
# hdfs dfs -mkdir /user/`whoami`/retail_db

# %%
# %%sh
#
# hdfs dfs -ls /user/`whoami`
# Out:
# Found 2 items
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:08 /user/itversity/.sparkStaging
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:27 /user/itversity/retail_db

# %%
# %%sh
#
# hdfs dfs -cp /public/retail_db/* /user/`whoami`/retail_db

# %%
# %%sh
#
# hdfs dfs -ls /user/`whoami`/retail_db
# Out:
# Found 9 items
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:28 /user/itversity/retail_db/categories
# -rw-r--r--   1 itversity supergroup   10303297 2022-05-29 17:28 /user/itversity/retail_db/create_db.sql
# -rw-r--r--   1 itversity supergroup       1748 2022-05-29 17:28 /user/itversity/retail_db/create_db_tables_pg.sql
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:28 /user/itversity/retail_db/customers
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:28 /user/itversity/retail_db/departments
# -rw-r--r--   1 itversity supergroup   10297372 2022-05-29 17:28 /user/itversity/retail_db/load_db_tables_pg.sql
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:28 /user/itversity/retail_db/order_items
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:28 /user/itversity/retail_db/orders
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:28 /user/itversity/retail_db/products

# %% [markdown]
# ```{note}
# This will fail as retail_db folder already exists.
# ```

# %%
# %%sh
#
# hdfs dfs -cp /public/retail_db /user/`whoami`
# Out:
# cp: `/user/itversity/retail_db/categories/part-00000': File exists
# cp: `/user/itversity/retail_db/create_db.sql': File exists
# cp: `/user/itversity/retail_db/create_db_tables_pg.sql': File exists
# cp: `/user/itversity/retail_db/customers/part-00000': File exists
# cp: `/user/itversity/retail_db/departments/part-00000': File exists
# cp: `/user/itversity/retail_db/load_db_tables_pg.sql': File exists
# cp: `/user/itversity/retail_db/order_items/part-00000': File exists
# cp: `/user/itversity/retail_db/orders/part-00000': File exists
# cp: `/user/itversity/retail_db/products/part-00000': File exists
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-12-a41fddd14079> in <module>
# ----> 1 get_ipython().run_cell_magic('sh', '', '\nhdfs dfs -cp /public/retail_db /user/`whoami`\n')
#
# ~/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2369             with self.builtin_trap:
#    2370                 args = (magic_arg_s, cell)
# -> 2371                 result = fn(*args, **kwargs)
#    2372             return result
#    2373
#
# ~/.local/lib/python3.6/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# ~/.local/lib/python3.6/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/.local/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/.local/lib/python3.6/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'\nhdfs dfs -cp /public/retail_db /user/`whoami`\n'' returned non-zero exit status 1.

# %% [markdown]
# ```{note}
# Alternative approach, where the folder and contents are copied directly.
# ```

# %%
# %%sh
#
# hdfs dfs -rm -R -skipTrash /user/`whoami`/retail_db
# Out:
# Deleted /user/itversity/retail_db

# %%
# %%sh
#
# hdfs dfs -ls /user/`whoami`
# Out:
# Found 1 items
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:08 /user/itversity/.sparkStaging

# %%
# %%sh
#
# hdfs dfs -cp /public/retail_db /user/`whoami`

# %%
# %%sh
#
# hdfs dfs -ls -R /user/`whoami`/retail_db
# Out:
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:28 /user/itversity/retail_db/categories
# -rw-r--r--   1 itversity supergroup       1029 2022-05-29 17:28 /user/itversity/retail_db/categories/part-00000
# -rw-r--r--   1 itversity supergroup   10303297 2022-05-29 17:28 /user/itversity/retail_db/create_db.sql
# -rw-r--r--   1 itversity supergroup       1748 2022-05-29 17:28 /user/itversity/retail_db/create_db_tables_pg.sql
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:28 /user/itversity/retail_db/customers
# -rw-r--r--   1 itversity supergroup     953719 2022-05-29 17:28 /user/itversity/retail_db/customers/part-00000
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:28 /user/itversity/retail_db/departments
# -rw-r--r--   1 itversity supergroup         60 2022-05-29 17:28 /user/itversity/retail_db/departments/part-00000
# -rw-r--r--   1 itversity supergroup   10297372 2022-05-29 17:28 /user/itversity/retail_db/load_db_tables_pg.sql
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:28 /user/itversity/retail_db/order_items
# -rw-r--r--   1 itversity supergroup    5408880 2022-05-29 17:28 /user/itversity/retail_db/order_items/part-00000
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:28 /user/itversity/retail_db/orders
# -rw-r--r--   1 itversity supergroup    2999944 2022-05-29 17:28 /user/itversity/retail_db/orders/part-00000
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:28 /user/itversity/retail_db/products
# -rw-r--r--   1 itversity supergroup     174155 2022-05-29 17:28 /user/itversity/retail_db/products/part-00000

# %% [markdown]
# * We can also use patterns while using `cp` command to copy files within HDFS. Also, we can pass multiple files or folders in HDFS to `cp` command.

# %%
# %%sh
#
# hdfs dfs -rm -R -skipTrash /user/`whoami`/retail_db
# Out:
# Deleted /user/itversity/retail_db

# %%
# %%sh
#
# hdfs dfs -ls /user/`whoami`
# Out:
# Found 1 items
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:08 /user/itversity/.sparkStaging

# %%
# %%sh
#
# hdfs dfs -mkdir /user/`whoami`/retail_db

# %%
# %%sh
#
# hdfs dfs -cp /public/retail_db/order* /user/`whoami`/retail_db

# %%
# %%sh
#
# hdfs dfs -ls /user/`whoami`/retail_db
# Out:
# Found 2 items
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:29 /user/itversity/retail_db/order_items
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:29 /user/itversity/retail_db/orders

# %%
# %%sh
#
# hdfs dfs -cp /public/retail_db/departments /public/retail_db/products /user/`whoami`/retail_db

# %%
# %%sh
#
# hdfs dfs -ls /user/`whoami`/retail_db
# Out:
# Found 4 items
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:29 /user/itversity/retail_db/departments
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:29 /user/itversity/retail_db/order_items
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:29 /user/itversity/retail_db/orders
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:29 /user/itversity/retail_db/products

# %%
# %%sh
#
# hdfs dfs -cp /public/retail_db/categories /public/retail_db/customers /user/`whoami`/retail_db

# %%
# %%sh
#
# hdfs dfs -ls /user/`whoami`/retail_db
# Out:
# Found 6 items
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:29 /user/itversity/retail_db/categories
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:29 /user/itversity/retail_db/customers
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:29 /user/itversity/retail_db/departments
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:29 /user/itversity/retail_db/order_items
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:29 /user/itversity/retail_db/orders
# drwxr-xr-x   - itversity supergroup          0 2022-05-29 17:29 /user/itversity/retail_db/products
